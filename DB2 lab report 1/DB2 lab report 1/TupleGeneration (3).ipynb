# %%
import random
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("adjusted-name-combinations-list.csv")

# %% [markdown]
# Source for above csv: https://github.com/fivethirtyeight/data/tree/master/most-common-name

# %%
print(df)
# Out:
#      Unnamed: 0 FirstName    Surname  Adjustment          cleanName  \
# 0             1     James      Smith        21.1        james smith
# 1             2   Michael      Smith         5.6      michael smith
# 2             3    Robert      Smith         8.7       robert smith
# 3             4     David      Smith        10.8        david smith
# 4             5     James    Johnson         9.6      james johnson
# 5             6   Michael    Johnson        -4.8    michael johnson
# 6             7   William      Smith        16.6      william smith
# 7             8     James   Williams        20.7     james williams
# 8             9    Robert    Johnson         5.9     robert johnson
# 9            10      Mary      Smith        14.7         mary smith
# 10           11     James      Brown        25.4        james brown
# 11           12      John      Smith       -23.5         john smith
# 12           13     David    Johnson         3.5      david johnson
# ...

# %%
ListOfNames = df['FirstName'].tolist()

# %%
print(ListOfNames)
# Out:
# ['James', 'Michael', 'Robert', 'David', 'James', 'Michael', 'William', 'James', 'Robert', 'Mary', 'James', 'John', 'David', 'Michael', 'Maria', 'Michael', 'Michael', 'James', 'Maria', 'Robert', 'Michael', 'Robert', 'Robert', 'William', 'James', 'Mary', 'Maria', 'Charles', 'David', 'Robert', 'James', 'John', 'Richard', 'David', 'David', 'Michael', 'William', 'David', 'Mary', 'Jennifer', 'William', 'John', 'John', 'Daniel', 'Thomas', 'Linda', 'James', 'Robert', 'Mary', 'Mary', 'Patricia', 'James', 'James', 'William', 'John', 'Charles', 'William', 'John', 'Richard', 'James', 'Robert', 'Barbara', 'Michael', 'James', 'Michael', 'James', 'Joseph', 'James', 'Mary', 'Robert', 'Robert', 'Charles', 'Jennifer', 'Michael', 'John', 'Michael', 'James', 'Mark', 'Michael', 'David', 'Linda', 'Elizabeth', 'Mary', 'James', 'Michael', 'Charles', 'Daniel', 'James', 'Michael', 'Daniel', 'David', 'Thomas', 'John', 'Robert', 'John', 'Richard', 'Charles', 'Mark', 'Robert', 'Patricia', 'Michael', 'David', 'Ro
# ...

# %%
for i in range (301, 400):
    print ("INSERT INTO Sailor(sid, sname, rating, age) VALUES (" + str(i) + ",'" + ListOfNames[i] + "'," + str(random.randint(0,10)) + "," + str(round(random.uniform(16, 100), 1)) + ");")
# Out:
# INSERT INTO Sailor(sid, sname, rating, age) VALUES (301,'Linda',5,84.3);
# INSERT INTO Sailor(sid, sname, rating, age) VALUES (302,'Mark',10,35.4);
# INSERT INTO Sailor(sid, sname, rating, age) VALUES (303,'Thomas',9,49.7);
# INSERT INTO Sailor(sid, sname, rating, age) VALUES (304,'Joseph',5,50.6);
# INSERT INTO Sailor(sid, sname, rating, age) VALUES (305,'Linda',9,86.5);
# INSERT INTO Sailor(sid, sname, rating, age) VALUES (306,'Linda',0,32.1);
# INSERT INTO Sailor(sid, sname, rating, age) VALUES (307,'Susan',10,17.2);
# INSERT INTO Sailor(sid, sname, rating, age) VALUES (308,'Elizabeth',4,26.7);
# INSERT INTO Sailor(sid, sname, rating, age) VALUES (309,'Joseph',5,21.7);
# INSERT INTO Sailor(sid, sname, rating, age) VALUES (310,'Richard',8,31.4);
# INSERT INTO Sailor(sid, sname, rating, age) VALUES (311,'Barbara',5,85.4);
# INSERT INTO Sailor(sid, sname, rating, age) VALUES (312,'Joseph',10,49.4);
# INSERT INTO Sailor(sid, sname, rating, age) VALUES (313,'Linda',4,59.5);
# ...

# %%
ListOfBoats = df["Surname"].tolist()

# %%
ListOfColours = ["red", "orange", "yellow", "green", "blue", "purple", "black", "white", "grey", "silver", "gold"]

# %%
for i in range(105, 305):
    print("INSERT INTO Boat(bid, bname, color) VALUES (" + str(i) + ",'" + ListOfBoats[i] + "','" + ListOfColours[i%11] + "');")
# Out:
# INSERT INTO Boat(bid, bname, color) VALUES (105,'Thomas','black');
# INSERT INTO Boat(bid, bname, color) VALUES (106,'Martin','white');
# INSERT INTO Boat(bid, bname, color) VALUES (107,'Miller','grey');
# INSERT INTO Boat(bid, bname, color) VALUES (108,'White','silver');
# INSERT INTO Boat(bid, bname, color) VALUES (109,'Thomas','gold');
# INSERT INTO Boat(bid, bname, color) VALUES (110,'Johnson','red');
# INSERT INTO Boat(bid, bname, color) VALUES (111,'Smith','orange');
# INSERT INTO Boat(bid, bname, color) VALUES (112,'Thompson','yellow');
# INSERT INTO Boat(bid, bname, color) VALUES (113,'Rodriguez','green');
# INSERT INTO Boat(bid, bname, color) VALUES (114,'White','blue');
# INSERT INTO Boat(bid, bname, color) VALUES (115,'Wilson','purple');
# INSERT INTO Boat(bid, bname, color) VALUES (116,'Lee','black');
# INSERT INTO Boat(bid, bname, color) VALUES (117,'Jones','white');
# INSERT INTO Boat(bid, bname, color) VALUES (118,'Taylor','grey');
# ...

# %%
for i in range (105, 355): 
    print ("INSERT INTO Reserve(sid, bid, day) VALUES (" + str(random.randint(100, 299)) + "," + str(random.randint(105, 304))+ ",'" + str(random.randint(1998, 2018)) + "-" + str(random.randint(1,12)) + "-" + str(random.randint(1,28)) + "');")
# Out:
# INSERT INTO Reserve(sid, bid, day) VALUES (277,119,'2004-10-15');
# INSERT INTO Reserve(sid, bid, day) VALUES (103,148,'2000-8-12');
# INSERT INTO Reserve(sid, bid, day) VALUES (130,193,'2008-5-27');
# INSERT INTO Reserve(sid, bid, day) VALUES (268,135,'2004-5-3');
# INSERT INTO Reserve(sid, bid, day) VALUES (191,215,'2017-8-17');
# INSERT INTO Reserve(sid, bid, day) VALUES (241,151,'2004-7-27');
# INSERT INTO Reserve(sid, bid, day) VALUES (116,271,'2017-12-25');
# INSERT INTO Reserve(sid, bid, day) VALUES (102,231,'2016-11-8');
# INSERT INTO Reserve(sid, bid, day) VALUES (174,284,'2003-11-19');
# INSERT INTO Reserve(sid, bid, day) VALUES (233,159,'2006-12-9');
# INSERT INTO Reserve(sid, bid, day) VALUES (170,184,'2017-8-3');
# INSERT INTO Reserve(sid, bid, day) VALUES (227,238,'2015-10-12');
# INSERT INTO Reserve(sid, bid, day) VALUES (230,228,'2009-6-3');
# INSERT INTO Reserve(sid, bid, day) VALUES (248,253,'2006-5-12');
# ...

# %%
df = pd.read_csv("female_cy1946_top.csv")

# %% [markdown]
# Source for above csv: https://data.sa.gov.au/data/dataset/popular-baby-names

# %%
print(df)
# Out:
#       Given Name  Amount Position
# 0       MARGARET     346        1
# 1          HELEN     258        2
# 2      CHRISTINE     250        3
# 3         JUDITH     231        4
# 4       PATRICIA     195        5
# 5         PAMELA     186        6
# 6       JENNIFER     183        7
# 7      ELIZABETH     151        8
# 8        BARBARA     146       =9
# 9         SANDRA     146       =9
# 10       HEATHER     141       11
# 11      LORRAINE     138       12
# 12        DIANNE     133       13
# 13         JANET     125       14
# 14          MARY     123       15
# 15      BEVERLEY     120      =16
# 16       LYNETTE     120      =16
# 17         SUSAN     118       18
# 18      ROSEMARY     112       19
# 19       RAELENE     110       20
# 20        JANICE     106       21
# 21       JILLIAN     100       22
# 22       PAULINE      98       23
# 23      KATHLEEN      87       24
# 24       MARILYN      82       25
# 25          ANNE      80       26
# ...

# %%
ListOfNames = df['Given Name'].tolist()

# %%
for i in range (787):
    print ("INSERT INTO Sailor(sid, sname, rating, age) VALUES (" + str(i+400) + ",'" + ListOfNames[i] + "'," + str(random.randint(0,10)) + "," + str(round(random.uniform(16, 100), 1)) + ");")
# Out:
# INSERT INTO Sailor(sid, sname, rating, age) VALUES (400,'MARGARET',0,81.7);
# INSERT INTO Sailor(sid, sname, rating, age) VALUES (401,'HELEN',1,24.5);
# INSERT INTO Sailor(sid, sname, rating, age) VALUES (402,'CHRISTINE',6,92.6);
# INSERT INTO Sailor(sid, sname, rating, age) VALUES (403,'JUDITH',8,19.9);
# INSERT INTO Sailor(sid, sname, rating, age) VALUES (404,'PATRICIA',8,77.6);
# INSERT INTO Sailor(sid, sname, rating, age) VALUES (405,'PAMELA',3,24.9);
# INSERT INTO Sailor(sid, sname, rating, age) VALUES (406,'JENNIFER',3,28.5);
# INSERT INTO Sailor(sid, sname, rating, age) VALUES (407,'ELIZABETH',9,99.1);
# INSERT INTO Sailor(sid, sname, rating, age) VALUES (408,'BARBARA',3,39.5);
# INSERT INTO Sailor(sid, sname, rating, age) VALUES (409,'SANDRA',8,22.9);
# INSERT INTO Sailor(sid, sname, rating, age) VALUES (410,'HEATHER',4,66.3);
# INSERT INTO Sailor(sid, sname, rating, age) VALUES (411,'LORRAINE',3,70.4);
# ...

# %%
df = pd.read_csv("male_cy2013_top.csv")

# %% [markdown]
# Source for above csv: https://data.sa.gov.au/data/dataset/popular-baby-names

# %%
print(df)
# Out:
#      Given Name  Amount Position
# 0        OLIVER     170        1
# 1       WILLIAM     118        2
# 2          NOAH     111        3
# 3          JACK     106        4
# 4         ETHAN     105        5
# 5         MASON     101        6
# 6       LACHLAN      99        7
# 7         HENRY      98        8
# 8         JAMES      97        9
# 9         LUCAS      94      =10
# 10          MAX      94      =10
# 11     HARRISON      92       12
# 12       THOMAS      88       13
# 13        JACOB      87       14
# 14       JOSHUA      86       15
# 15      CHARLIE      81       16
# 16    ALEXANDER      77      =17
# 17        OSCAR      77      =17
# 18       SAMUEL      77      =17
# 19         LIAM      76       20
# 20        ISAAC      74       21
# 21        HARRY      73       22
# 22       HUDSON      72       23
# 23        TYLER      71       24
# 24        JAXON      66      =25
# 25        RILEY      66      =25
# 26       COOPER      64      =27
# ...

# %%
ListOfBoats = df["Given Name"].tolist()

# %%
for i in range(2418):
    print("INSERT INTO Boat(bid, bname, color) VALUES (" + str(i+400) + ",'" + ListOfBoats[i] + "','" + ListOfColours[i%11] + "');")
# Out:
# INSERT INTO Boat(bid, bname, color) VALUES (400,'OLIVER','red');
# INSERT INTO Boat(bid, bname, color) VALUES (401,'WILLIAM','orange');
# INSERT INTO Boat(bid, bname, color) VALUES (402,'NOAH','yellow');
# INSERT INTO Boat(bid, bname, color) VALUES (403,'JACK','green');
# INSERT INTO Boat(bid, bname, color) VALUES (404,'ETHAN','blue');
# INSERT INTO Boat(bid, bname, color) VALUES (405,'MASON','purple');
# INSERT INTO Boat(bid, bname, color) VALUES (406,'LACHLAN','black');
# INSERT INTO Boat(bid, bname, color) VALUES (407,'HENRY','white');
# INSERT INTO Boat(bid, bname, color) VALUES (408,'JAMES','grey');
# INSERT INTO Boat(bid, bname, color) VALUES (409,'LUCAS','silver');
# INSERT INTO Boat(bid, bname, color) VALUES (410,'MAX','gold');
# INSERT INTO Boat(bid, bname, color) VALUES (411,'HARRISON','red');
# INSERT INTO Boat(bid, bname, color) VALUES (412,'THOMAS','orange');
# INSERT INTO Boat(bid, bname, color) VALUES (413,'JACOB','yellow');
# ...

# %%
for i in range (787): 
    print ("INSERT INTO Reserve(sid, bid, day) VALUES (" + str(i+400) + "," + str(i+400)+ ",'" + str(random.randint(1998, 2018)) + "-" + str(random.randint(1,12)) + "-" + str(random.randint(1,28)) + "');")
# Out:
# INSERT INTO Reserve(sid, bid, day) VALUES (400,400,'2002-4-24');
# INSERT INTO Reserve(sid, bid, day) VALUES (401,401,'2013-4-4');
# INSERT INTO Reserve(sid, bid, day) VALUES (402,402,'2000-3-23');
# INSERT INTO Reserve(sid, bid, day) VALUES (403,403,'2003-11-3');
# INSERT INTO Reserve(sid, bid, day) VALUES (404,404,'2000-10-14');
# INSERT INTO Reserve(sid, bid, day) VALUES (405,405,'2016-8-27');
# INSERT INTO Reserve(sid, bid, day) VALUES (406,406,'2016-4-15');
# INSERT INTO Reserve(sid, bid, day) VALUES (407,407,'1998-5-28');
# INSERT INTO Reserve(sid, bid, day) VALUES (408,408,'2004-7-23');
# INSERT INTO Reserve(sid, bid, day) VALUES (409,409,'2012-8-28');
# INSERT INTO Reserve(sid, bid, day) VALUES (410,410,'2007-2-27');
# INSERT INTO Reserve(sid, bid, day) VALUES (411,411,'2018-10-19');
# INSERT INTO Reserve(sid, bid, day) VALUES (412,412,'1998-12-6');
# INSERT INTO Reserve(sid, bid, day) VALUES (413,413,'2007-12-25');
# ...
